# %%
import sys, os
sys.path.append(os.path.abspath(".."))

# %%
from src.feature_engineering.features import feature_engineering, save_processed
import pandas as pd

df = pd.read_csv("../data/processed/trade_cleaned.csv")
df = feature_engineering(df)
save_processed(df)
# Out:
# Saved processed file to: ../data/processed/trade_cleaned.csv

# %%
import pandas as pd
import dtale

df = pd.read_csv("../data/processed/trade_cleaned.csv")
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-GJN966GE:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
