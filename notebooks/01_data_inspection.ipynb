# %%
import pandas as pd

file_path = "../data/raw/sample_data_2017_2025.xlsx"
df = pd.read_excel(file_path)

df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2079 entries, 0 to 2078
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PORT CODE          2079 non-null   object
#  1   DATE               2079 non-null   object
#  2   IEC                2079 non-null   int64
#  3   HS CODE            2079 non-null   int64
#  4   GOODS DESCRIPTION  2079 non-null   object
#  5   Master category    0 non-null      float64
#  6   Model Name         0 non-null      float64
#  7   Model Number       0 non-null      float64
#  8   Capacity           0 non-null      float64
#  9   Qty                0 non-null      float64
#  10  Unit of measure    0 non-null      float64
#  11  Price              0 non-null      float64
#  12  Unit of measure.1  0 non-null      float64
#  13  QUANTITY           2079 non-null   float64
#  14  UNIT               2079 non-null   object
# ...

# %%
df['DATE'] = pd.to_datetime(df['DATE'], format="%Y-%m-%d", errors='coerce')

print(df.head())
df['DATE'].dt.year.unique()
# Out:
#   PORT CODE       DATE        IEC   HS CODE  \
# 0    INNSA1 2025-10-28  301049751  73239990
# 1    INNSA1 2025-10-28  301049751  73231000
# 2    INNSA1 2025-10-23  301049751  73239990
# 3    INNSA1 2025-10-13  301049751  73239990
# 4    INNSA1 2025-10-13  301049751  73239990
#
#                                    GOODS DESCRIPTION  Master category  \
# 0  TH5170 STEEL CUTLERY HOLDER (QTY:600 PCS/USD 2...              NaN
# 1  8001-2 STEEL SCRUBBER 2PCS SET (QTY: 336000 SE...              NaN
# 2  MILD STEEL MULTI FUNCTION CLOTH STAND (RYX-02-...              NaN
# 3  SB-12 STEEL TEA STRAINER BIG (QTY 6336 PCS/USD...              NaN
# 4  SB-12 STEEL TEA STRAINER BIG (QTY 43038 PCS/US...              NaN
#
#    Model Name  Model Number  Capacity  Qty  Unit of measure  Price  \
# 0         NaN           NaN       NaN  NaN              NaN    NaN
# 1         NaN           NaN       NaN  NaN              NaN    NaN
# 2         NaN           NaN       NaN  NaN              NaN    NaN
# ...

# %%
df['UNIT'].unique()
# Out:
# array(['KGS', 'NOS', 'PCS', 'KGS ', 'KG', 'SET'], dtype=object)

# %%
df['GOODS DESCRIPTION'].sample(10)
# Out:
# 563     STEEL LUNCH BOX (6588) (QTY: 1200 NOS/USD 2.45...
# 1103    STEEL TEA STRAINER BIG - SB-12 (QTY:26400 PCS/...
# 1402    STEEL RECTANGLE CONTAINER- 6901(TOTAL 2400 PCS...
# 239     STEEL FRUIT BASKET (SD1078-B) (QTY: 20160 PCS/...
# 469     AM-393 STAINLESS STEEL SPORTS BOTTLE 750ML (QT...
# 1269    STEEL SCRUBBER 2PCS SET - 8001-2 (QTY-166800 S...
# 1587    03-027I FAMILY CLOTH RACK 3LAYERS (3648 PCS) (...
# 1557    STAINLESS STEEL SPORTS BOTTLE 650ML S115-NP-21...
# 306     MILD STEEL MULTI FUNCTION CLOTH STAND (RYX-02-...
# 2032    STEEL SCRUBBER 3PCS SET-ANGW11 (TOTAL NET WT.7...
# Name: GOODS DESCRIPTION, dtype: object

# %%
df[['TOTAL VALUE_INR', 'DUTY PAID_INR']].describe()
# Out:
#        TOTAL VALUE_INR  DUTY PAID_INR
# count     2.079000e+03   2.079000e+03
# mean      2.017286e+06   6.878388e+05
# std       1.694160e+06   6.223662e+05
# min       1.882250e+03   0.000000e+00
# 25%       7.717038e+05   2.092378e+05
# 50%       1.648069e+06   5.411963e+05
# 75%       2.838890e+06   9.742361e+05
# max       1.329217e+07   4.870250e+06
